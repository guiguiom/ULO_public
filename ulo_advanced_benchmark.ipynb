# %%
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns 
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import cvxpy as cp
import time
import gurobipy
import pandas as pd

np.random.seed(230824)
# Out:
# (CVXPY) Jul 10 06:45:42 PM: Encountered unexpected exception importing solver PROXQP:
# ImportError("dlopen(/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/cmeel.prefix/lib/python3.12/site-packages/proxsuite/instructionset.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libc++.1.dylib\n  Referenced from: <1A57AE5C-C7A4-3364-A443-4BC8EA7A0D79> /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/cmeel.prefix/lib/python3.12/site-packages/proxsuite/instructionset.cpython-312-darwin.so\n  Reason: tried: '/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/var/folders/mj/dx2cc6hn6h9br7vt9hz4n06m0000gn/T/cmeel-0at3h7tz/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/var/folders/mj/dx2cc6hn6h9br7vt9hz4n06m0000gn/T/cmeel-0at3h7tz/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/var/folders/mj/dx2cc6hn6h9br7vt9hz4n06m0000gn/T/cmeel-0at3h7tz/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/var/folders/mj/dx2cc6hn6h9br7vt9hz4n06m0000gn/T/cmeel-0at3h7tz/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file)")

# %%
'''
data generation
'''

# dimensions
n,m,d = int(2e2),int(1e3),int(100)
TIME_LIMIT = 500
main_scale_beta = 25.0 
inflation_factor = .2 
rank_B_dev = min(4,d)


def data_generator(delta_beta=1,impact_B_dev = .2):
    
    # ref vectors
    bar_beta = np.random.randint(-int(max(1,abs(main_scale_beta))),int(max(1,abs(main_scale_beta)))+1,d)/int(max(1,abs(main_scale_beta)))
    norm_bar_beta = np.linalg.norm(bar_beta)
    pre_diag_B_ref = np.random.uniform(.25,1.0,d)
    diag_B_ref = pre_diag_B_ref / np.sum(pre_diag_B_ref) * d 
    mean_EV = np.mean(diag_B_ref)
    R_base = np.sqrt(np.sum(np.abs((diag_B_ref**(1/2))*np.ones(d))**2)*(1+inflation_factor))
    
    # deviations
    betas = np.outer(np.ones(n),bar_beta)
    for i in range(n):
        dev_i = np.random.normal(0,1,d)
        dev_i /= np.linalg.norm(dev_i)
        betas[i] += dev_i*delta_beta*norm_bar_beta
    
    B_devs = []
    for j in range(m):
        # Generate a random matrix with standard normal entries
        H = np.random.standard_normal(size=(d, d))
        # Compute QR decomposition
        Q, R = np.linalg.qr(H)
        # Adjust signs of Q to ensure uniform distribution
        diag_signs = np.sign(np.diag(R))
        diag_signs[diag_signs == 0] = 1  # Handle zero signs (unlikely)
        Q = Q * diag_signs  # Multiply each column by its sign
        B_devs.append(Q[:rank_B_dev,:])


    return diag_B_ref,betas,B_devs

# %%
dic_results = {'method':[],'rel_dev_obj':[],'rel_dev_cstr':[],'time':[],'F_hat':[],'rep':[],'F_check':[]}
N_reps = int(10)

my_env = gurobipy.Env()
my_env.setParam('TimeLimit', TIME_LIMIT) # in seconds


for db in [.1,.5,1,5,10]:
    for iBd in [.1,.5,2]:

        print('=> data generation for db = '+str(db)+' and iBd = '+str(iBd))
        print(' ')
        
        diag_B_ref,betas,B_devs = data_generator(delta_beta=db,impact_B_dev =iBd)
        mean_EV = np.mean(diag_B_ref)
        R_base = np.sqrt(np.sum(np.abs(diag_B_ref*np.ones(d))**2)*(1+inflation_factor))

        '''
        cstr generator
        ''' 
        def DOMGEN(cvxpy_var,S=np.arange(m),sc_factor=iBd):
            buf = []
            for j in S:
                buf.append(cp.sum_squares(cp.multiply(diag_B_ref**(1/2),cvxpy_var))+sc_factor*mean_EV*cp.sum_squares(B_devs[int(j)]@cvxpy_var)-R_base**2<=0)
            return buf.copy()
        '''
        helper numpy functions
        '''
        def c_values(x,S=np.arange(m),sc_factor=iBd):
            inners = np.array(B_devs)[S]@x
            return np.sum((diag_B_ref**(1/2)*x)**2)-R_base**2 + sc_factor*mean_EV*np.sum(inners**2,1)
        
        def active_cstr(x,sc_factor_bis=iBd,feasactive=1e-4):
            cvals = c_values(x,sc_factor=sc_factor_bis)
            return np.where(cvals>=-feasactive)[0]
        
        def f_values(x,H=np.arange(n)):
            return betas[H]@x
        
        def active_f(x,rho=1e-3):
            fvals = f_values(x)
            return np.where(fvals<=np.min(fvals)+rho)[0]
        
        def F(x,feastol=1e-5):
            if np.max(c_values(x))>=feastol:
                return np.inf
            else:
                return np.min(f_values(x))


        ############################ solving time

        ## CVXPY global 
        x_glob = cp.Variable(d)
        cstrs_full = DOMGEN(x_glob)
        lin_param_glob = cp.Parameter(d)
        eta_glob = cp.Variable(1)
        t_glob = cp.Variable(n,boolean=True)
        
        bigMs = np.zeros((n,n))
        
        for i_plus in range(n):
            for i in range(n):
                # closed-forms here
                if i_plus!=i:
                    delta_betas = betas[i_plus]-betas[i]
                    tilde_lin_c = delta_betas*(diag_B_ref**(-1/2))
                    bigMs[i_plus,i] = np.linalg.norm(tilde_lin_c)*R_base
        
        cstrs_full += [cp.sum(t_glob)==1]
        
        for i_plus in range(n):
            cstrs_full += [betas[i_plus]@x_glob<=eta_glob[0]+bigMs[i_plus]@t_glob]
        
        prob_glob = cp.Problem(cp.Minimize(eta_glob[0]),cstrs_full)
        t_start = time.time()
        prob_glob.solve(solver=cp.GUROBI,verbose=True,env=my_env)
        t_end = time.time()

        dic_results['method'].append('bigM (direct)')
        dic_results['rel_dev_obj'].append(db)
        dic_results['rel_dev_cstr'].append(iBd)
        dic_results['time'].append(t_end-t_start)
        dic_results['F_hat'].append(prob_glob.value)
        dic_results['rep'].append(1)
        if prob_glob.status==cp.OPTIMAL:
            dic_results['F_check'].append(prob_glob.value)
        else:
            grb_model = prob_glob.solver_stats.extra_stats
            best_bound = grb_model.ObjBound
            dic_results['F_check'].append(best_bound)

        print(' ')
        print('end of glob')
        print(' ')


        ## CVXPY ULO 
        x_ulo = cp.Variable(d)
        cstrs_full = DOMGEN(x_ulo)
        lin_param_ulo = cp.Parameter(d)
        obj_ulo = cp.Minimize(lin_param_ulo@x_ulo)
        prob_ulo_full = cp.Problem(obj_ulo,cstrs_full)
        
        '''
        inplace version of ULO
        '''
        def ULO(i_hat,epsilon_tilde=1e-2,epsilon=1e-2,verb_lvl=2,time_lim=TIME_LIMIT):
        
            if verb_lvl>0:
                print('ULO start')
                print(' ')
            
            ## init.
            H,S = [],[]
            F_check,F_hat = -np.inf,np.inf
            rho = 1e-3
            i_star = None
            bar_x = None
            x_out = None
            k = 0
        
            nus = np.inf*np.ones(n)

            inner_time_start = time.time()
        
            ## oracles set-up 
            
            ## main loop
            while k==0 or F_hat-F_check>max(epsilon,max(1,abs(F_hat))*epsilon_tilde):
        
                # -> phase (a) <- 
                R,V = np.inf,[i_hat]
                while len(V)>0:
                    bar_i = np.random.choice(V)
                    lin_param_ulo.value = betas[bar_i]
                    H.append(bar_i)
                    ### start oracle call 
                    if verb_lvl>=1:
                        print('tested piece #'+str(bar_i))
                    prob_ulo_full.solve(solver=cp.MOSEK,warm_start=True)
                    x_tilde = x_ulo.value
                    nu_bar_i = prob_ulo_full.value
                    if verb_lvl>=1:
                        print('value: '+str(nu_bar_i))
                    nus[bar_i] = nu_bar_i
                    ### end oracle call 
                    if nu_bar_i >= R:
                        V = np.setdiff1d(V,[bar_i])
                    else:
                        V = np.setdiff1d(active_f(x_tilde,rho),H)
                        R = F(x_tilde)
                        i_star = bar_i
                        bar_x = x_tilde

                    if time.time()-inner_time_start>time_lim:
                        if verb_lvl>0:
                            print('time limit reached...')
                        return x_out,F_hat,F_check
        
                ### update of the set of selected constraints
                S = np.union1d(S,[np.random.choice(np.setdiff1d(np.arange(m),S))])
                S = np.union1d(S,active_cstr(bar_x))
        
                val_bar_x = F(bar_x)
                if val_bar_x<F_hat:
                    F_hat,x_out = val_bar_x,bar_x
        
                if F_hat-F_check<=max(epsilon,max(1,abs(F_hat))*epsilon_tilde):
                    if verb_lvl>0:
                        print(' ')
                        print('early convergence within iteration #'+str(k))
                    return x_out,F_hat,F_check
        
                if verb_lvl>=1:
                    print('F_hat = '+str(F_hat))
                    if verb_lvl>=2:
                        print('|S| = '+str(len(S)))
        
                # -> phase (b) <-
                for i in np.setdiff1d(range(n),H):
                    ### start oracle call 
                    cstrs_S = DOMGEN(x_ulo,S)
                    lin_param_ulo.value = betas[i]
                    prob_ulo_S = cp.Problem(obj_ulo,cstrs_S)
                    if verb_lvl>=3:
                        print('tested (LB) piece #'+str(i))
                    prob_ulo_S.solve(solver=cp.MOSEK,warm_start=True)
                    nus[i] = prob_ulo_S.value
                    if verb_lvl>=3:
                        print('value: '+str(nus[i]))
                    ### end oracle call 
                    if time.time()-inner_time_start>time_lim:
                        if verb_lvl>0:
                            print('time limit reached...')
                        return x_out,F_hat,F_check
                    
                i_hat = np.argmin(nus)
                F_check = max(F_check,nus[i_hat])
                if verb_lvl>=1:
                    print('F_check = '+str(F_check))
        
                k += 1
                
            if verb_lvl>0:
                print(' ')
                print('convergence after '+str(k)+' iterations')
                
            return x_out,F_hat,F_check

        for _ in range(N_reps):
            t_start = time.time()
            x_out,F_hat,F_check = ULO(i_hat=np.random.choice(np.arange(n)),epsilon_tilde=1e-6,epsilon=1e-2)
            t_end = time.time()
            dic_results['method'].append('ULO')
            dic_results['rel_dev_obj'].append(db)
            dic_results['rel_dev_cstr'].append(iBd)
            dic_results['time'].append(t_end-t_start)
            dic_results['F_hat'].append(F_hat)
            dic_results['F_check'].append(F_check)
            dic_results['rep'].append(_)

        print(' ')
        print('end of ULO')
        print(' ')
    
        ## CVXPY ES
        x_es = cp.Variable(d)
        cstrs_full = DOMGEN(x_es)
        lin_param_es = cp.Parameter(d)
        obj_es = cp.Minimize(lin_param_es@x_es)
        prob_es_full = cp.Problem(obj_es,cstrs_full)
        times = []
        for i in np.random.choice(np.arange(n),size=int(n/10),replace=False):
            lin_param_es.value = betas[i]
            t_start = time.time()
            prob_es_full.solve(solver=cp.GUROBI)
            t_end = time.time()
            print('trial #i = '+str(i)+' took '+str(t_end-t_start)+' [s]')
            times.append(t_end-t_start)
        dic_results['method'].append('ES')
        dic_results['rel_dev_obj'].append(db)
        dic_results['rel_dev_cstr'].append(iBd)
        dic_results['time'].append(np.mean(times)*n)
        dic_results['F_hat'].append(F_hat)
        dic_results['F_check'].append(F_hat) # we assume F_hat is the good one ;) 
        dic_results['rep'].append(1)

        print(' ')
        print('end of ES')
        print(' ')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-07-09
# Set parameter TimeLimit to value 500
# => data generation for db = 0.1 and iBd = 0.1
#
# ===============================================================================
#                                      CVXPY
#                                      v1.6.5
# ===============================================================================
# (CVXPY) Jul 10 06:45:45 PM: Your problem has 301 variables, 1201 constraints, and 0 parameters.
# (CVXPY) Jul 10 06:45:45 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 10 06:45:45 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 10 06:45:45 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jul 10 06:45:45 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 06:45:45 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 10 06:45:45 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> GUROBI
# (CVXPY) Jul 10 06:45:45 PM: Applying reduction Dcp2Cone
# (CVXPY) Jul 10 06:45:46 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 10 06:45:46 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 10 06:46:00 PM: Applying reduction GUROBI
# (CVXPY) Jul 10 06:46:02 PM: Finished problem compilation (took 1.674e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 06:46:02 PM: Invoking solver GUROBI  to obtain a solution.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (mac64[x86] - Darwin 24.4.0 24E263)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  500
# QCPDual  1
#
# Optimize a model with 109201 rows, 110301 columns and 674200 nonzeros
# Model fingerprint: 0x9ee444ec
# Model has 2000 quadratic constraints
# Variable types: 110101 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [2e-06, 1e+01]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: -64.8198 -64.3998 -64.3658
#
# Time limit reached
# Best objective -6.481977262258e+01, best bound -7.047878890998e+01, gap 8.7304%
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 06:54:25 PM: Problem status: user_limit
# (CVXPY) Jul 10 06:54:25 PM: Optimal value: -6.482e+01
# (CVXPY) Jul 10 06:54:25 PM: Compilation took 1.674e+01 seconds
# (CVXPY) Jul 10 06:54:25 PM: Solver (including time spent in interface) took 5.027e+02 seconds
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/cvxpy/problems/problem.py:1504: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
#
# end of glob
#
# ULO start
#
# tested piece #137
# value: -63.93275663037058
# tested piece #12
# value: -65.19393331549723
# F_hat = -65.19393331549723
# |S| = 3
# F_check = -65.19393331549723
#
# convergence after 1 iterations
# ULO start
#
# tested piece #162
# value: -62.9775688981044
# tested piece #12
# value: -65.19393331549723
# F_hat = -65.19393331549723
# |S| = 3
# F_check = -65.19393331549723
#
# convergence after 1 iterations
# ULO start
#
# tested piece #175
# value: -62.48210444058179
# tested piece #12
# value: -65.19393331549723
# F_hat = -65.19393331549723
# |S| = 3
# F_check = -65.19393331549723
#
# convergence after 1 iterations
# ULO start
#
# tested piece #93
# value: -63.55789217515065
# tested piece #12
# value: -65.19393331549723
# F_hat = -65.19393331549723
# |S| = 3
# F_check = -65.19393331549723
#
# convergence after 1 iterations
# ULO start
#
# tested piece #104
# value: -62.572507440179926
# tested piece #12
# value: -65.19393331549723
# F_hat = -65.19393331549723
# |S| = 3
# F_check = -65.19393331549723
#
# convergence after 1 iterations
# ULO start
#
# tested piece #61
# value: -61.76637375209244
# tested piece #12
# value: -65.19393331549723
# F_hat = -65.19393331549723
# |S| = 3
# F_check = -65.19393331549723
#
# convergence after 1 iterations
# ULO start
#
# tested piece #2
# value: -62.140813664689915
# tested piece #12
# value: -65.19393331549723
# F_hat = -65.19393331549723
# |S| = 3
# F_check = -65.19393331549723
#
# convergence after 1 iterations
# ULO start
#
# tested piece #191
# value: -62.90441750426498
# tested piece #12
# value: -65.19393331549723
# F_hat = -65.19393331549723
# |S| = 3
# F_check = -65.19393331549723
#
# convergence after 1 iterations
# ULO start
#
# tested piece #79
# value: -64.76364848902813
# F_hat = -64.76364848902813
# |S| = 3
# F_check = -65.19393440069325
# tested piece #12
# value: -65.19393331549723
#
# early convergence within iteration #1
# ULO start
#
# tested piece #76
# value: -63.36288731990435
# tested piece #12
# value: -65.19393331549723
# F_hat = -65.19393331549723
# |S| = 3
# F_check = -65.19393331549723
#
# convergence after 1 iterations
#
# end of ULO
#
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-07-09
# trial #i = 1 took 28.505577087402344 [s]
# trial #i = 174 took 13.280332088470459 [s]
# trial #i = 46 took 12.93015432357788 [s]
# trial #i = 157 took 15.5676589012146 [s]
# trial #i = 3 took 14.287981748580933 [s]
# trial #i = 123 took 11.871157169342041 [s]
# trial #i = 73 took 11.827646970748901 [s]
# trial #i = 187 took 10.653556823730469 [s]
# trial #i = 134 took 12.939124822616577 [s]
# trial #i = 20 took 13.029773950576782 [s]
# trial #i = 171 took 11.523600101470947 [s]
# trial #i = 6 took 10.969917058944702 [s]
# trial #i = 48 took 12.231891870498657 [s]
# trial #i = 39 took 12.469922065734863 [s]
# trial #i = 9 took 11.946075201034546 [s]
# trial #i = 126 took 12.338973999023438 [s]
# trial #i = 12 took 11.591582298278809 [s]
# trial #i = 8 took 11.692490577697754 [s]
# trial #i = 82 took 11.671800136566162 [s]
# trial #i = 155 took 12.295993089675903 [s]
#
# end of ES
#
# => data generation for db = 0.1 and iBd = 0.5
#
# ===============================================================================
#                                      CVXPY
#                                      v1.6.5
# ===============================================================================
# (CVXPY) Jul 10 07:00:27 PM: Your problem has 301 variables, 1201 constraints, and 0 parameters.
# (CVXPY) Jul 10 07:00:27 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 10 07:00:27 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 10 07:00:27 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jul 10 07:00:27 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 07:00:28 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 10 07:00:28 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> GUROBI
# (CVXPY) Jul 10 07:00:28 PM: Applying reduction Dcp2Cone
# (CVXPY) Jul 10 07:00:28 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 10 07:00:28 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 10 07:00:42 PM: Applying reduction GUROBI
# (CVXPY) Jul 10 07:00:44 PM: Finished problem compilation (took 1.668e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 07:00:44 PM: Invoking solver GUROBI  to obtain a solution.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (mac64[x86] - Darwin 24.4.0 24E263)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  500
# QCPDual  1
#
# Optimize a model with 109201 rows, 110301 columns and 674200 nonzeros
# Model fingerprint: 0x14f24b7e
# Model has 2000 quadratic constraints
# Variable types: 110101 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [6e-07, 1e+01]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# No start values specified in MIP start
#
# Presolve removed 2600 rows and 2600 columns
# Presolve time: 2.48s
# Presolved: 108601 rows, 213701 columns, 777000 nonzeros
# Presolved model has 106000 quadratic constraint(s)
# Variable types: 213501 continuous, 200 integer (200 binary)
# Root relaxation presolve removed 99400 rows and 99400 columns
# Root relaxation presolve time: 3.96s
# Root relaxation presolved: 321201 rows, 426301 columns, 1414200 nonzeros
# Root relaxation presolved model has 106000 second-order cone constraints
# Root barrier log...
#
# Ordering time: 0.13s
#
# Barrier statistics:
#  Dense cols : 1100
#  Free vars  : 100
#  AA' NZ     : 1.336e+06
#  Factor NZ  : 3.523e+06 (roughly 300 MB of memory)
#  Factor Ops : 2.258e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.78453812e+03 -5.84107493e+06  6.98e+04 7.26e-01  8.13e+01     5s
#    1   2.45091437e+03 -3.14175022e+06  3.06e+04 1.08e-01  3.12e+01     5s
#    2   8.73623488e+02 -9.42019684e+05  8.67e+02 1.19e-07  2.33e+00     6s
#    3  -7.12408630e+00 -7.00488273e+04  9.54e-04 5.30e-09  1.30e-01     6s
#    4  -1.07620803e+01 -1.85388009e+03  1.05e-09 5.67e-11  3.43e-03     6s
#    5  -1.64259744e+01 -7.51223193e+02  4.41e-10 2.18e-11  1.37e-03     7s
#    6  -2.02670467e+01 -5.93208286e+02  3.62e-10 1.69e-11  1.07e-03     7s
#    7  -2.87889343e+01 -4.30364490e+02  2.34e-10 1.17e-11  7.47e-04     8s
work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -81.62737    0   10          -  -81.62737      -     -   42s
#      0     0  -81.62737    0   10          -  -81.62737      -     -   45s
# H    0     0                     -74.5833602  -81.62737  9.44%     -   74s
#      0     2  -81.62737    0   10  -74.58336  -81.62737  9.44%     -  157s
#      1     2  -81.58962    1   12  -74.58336  -81.62737  9.44%   0.0  191s
# *    2     2               1     -74.6450834  -81.58962  9.30%   0.0  191s
#      3     2  -81.56590    2   11  -74.64508  -81.58962  9.30%   0.0  218s
#      5     2  -81.56329    3   12  -74.64508  -81.56590  9.27%   0.0  248s
#      7     2  -81.54262    4   13  -74.64508  -81.56329  9.27%   0.0  281s
#      9     2  -81.52421    5   13  -74.64508  -81.54262  9.24%   0.0  315s
#     11     2  -81.50723    6   14  -74.64508  -81.52421  9.22%   0.0  352s
#     13     2  -81.47634    7   13  -74.64508  -81.50723  9.19%   0.0  393s
#     15     2  -81.42342    8   12  -74.64508  -81.47634  9.15%   0.0  417s
#     17     2  -81.41963    9   11  -74.64508  -81.42342  9.08%   0.0  442s
#     19     2  -81.41654   10   12  -74.64508  -81.41963  9.08%   0.0  468s
#     21     2  -81.40031   11   11  -74.64508  -81.41654  9.07%   0.0  496s
#
# Explored 23 nodes (0 simplex iterations) in 500.33 seconds (453.90 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: -74.6451
#
# Time limit reached
# Warning: max constraint violation (9.2054e-05) exceeds tolerance
# Best objective -7.464508337753e+01, best bound -8.140030919628e+01, gap 9.0498%
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 07:09:08 PM: Problem status: user_limit
# (CVXPY) Jul 10 07:09:08 PM: Optimal value: -7.465e+01
# (CVXPY) Jul 10 07:09:08 PM: Compilation took 1.668e+01 seconds
# (CVXPY) Jul 10 07:09:08 PM: Solver (including time spent in interface) took 5.035e+02 seconds
#
# end of glob
#
# ULO start
#
# tested piece #43
# value: -71.39865049615214
# tested piece #110
# value: -74.64507980130496
# F_hat = -74.64507980130497
# |S| = 6
# F_check = -74.64507980130496
#
# convergence after 1 iterations
# ULO start
#
# tested piece #45
# value: -72.36352210641863
# tested piece #110
# value: -74.64507980130496
# F_hat = -74.64507980130497
# |S| = 6
# F_check = -74.64507980130496
#
# convergence after 1 iterations
# ULO start
#
# tested piece #84
# value: -74.20952474690918
# F_hat = -74.20952474690918
# |S| = 7
# F_check = -74.6450845359515
# tested piece #110
# value: -74.64507980130496
#
# early convergence within iteration #1
# ULO start
#
# tested piece #150
# value: -71.6362245703942
# tested piece #110
# value: -74.64507980130496
# F_hat = -74.64507980130497
# |S| = 6
# F_check = -74.64507980130496
#
# convergence after 1 iterations
# ULO start
#
# tested piece #96
# value: -73.33047871653511
# tested piece #110
# value: -74.64507980130496
# F_hat = -74.64507980130497
# |S| = 6
# F_check = -74.64507980130496
#
# convergence after 1 iterations
# ULO start
#
# tested piece #15
# value: -72.14812839648391
# tested piece #110
# value: -74.64507980130496
# F_hat = -74.64507980130497
# |S| = 6
# F_check = -74.64507980130496
#
# convergence after 1 iterations
# ULO start
#
# tested piece #45
# value: -72.36352210641863
# tested piece #110
# value: -74.64507980130496
# F_hat = -74.64507980130497
# |S| = 6
# F_check = -74.64507980130496
#
# convergence after 1 iterations
# ULO start
#
# tested piece #2
# value: -73.5431099850407
# tested piece #110
# value: -74.64507980130496
# F_hat = -74.64507980130497
# |S| = 6
# F_check = -74.64507980130496
#
# convergence after 1 iterations
# ULO start
#
# tested piece #80
# value: -72.36744297924504
# tested piece #110
# value: -74.64507980130496
# F_hat = -74.64507980130497
# |S| = 6
# F_check = -74.64507980130496
#
# convergence after 1 iterations
# ULO start
#
# tested piece #149
# value: -73.70011738009977
# tested piece #110
# value: -74.64507980130496
# F_hat = -74.64507980130497
# |S| = 6
# F_check = -74.64507980130496
#
# convergence after 1 iterations
#
# end of ULO
#
# trial #i = 167 took 23.86672616004944 [s]
# trial #i = 165 took 9.466537952423096 [s]
# trial #i = 31 took 11.496833801269531 [s]
# trial #i = 157 took 9.368465185165405 [s]
# trial #i = 43 took 11.22277307510376 [s]
# trial #i = 57 took 12.45979118347168 [s]
# trial #i = 143 took 14.610640048980713 [s]
# trial #i = 129 took 13.635379076004028 [s]
# trial #i = 182 took 15.976871013641357 [s]
# trial #i = 70 took 13.901005983352661 [s]
# trial #i = 175 took 14.897536754608154 [s]
# trial #i = 76 took 14.598098039627075 [s]
# trial #i = 138 took 14.279947996139526 [s]
# trial #i = 59 took 13.089164972305298 [s]
# trial #i = 109 took 13.259357929229736 [s]
# trial #i = 161 took 12.797910690307617 [s]
# trial #i = 21 took 13.78657579421997 [s]
# trial #i = 54 took 13.278276205062866 [s]
# trial #i = 130 took 14.44382119178772 [s]
# trial #i = 15 took 13.42848014831543 [s]
#
# end of ES
#
# => data generation for db = 0.1 and iBd = 2
#
# ===============================================================================
#                                      CVXPY
#                                      v1.6.5
# ===============================================================================
# (CVXPY) Jul 10 07:15:25 PM: Your problem has 301 variables, 1201 constraints, and 0 parameters.
# (CVXPY) Jul 10 07:15:26 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 10 07:15:26 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 10 07:15:26 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jul 10 07:15:26 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 07:15:26 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 10 07:15:26 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> GUROBI
# (CVXPY) Jul 10 07:15:26 PM: Applying reduction Dcp2Cone
# (CVXPY) Jul 10 07:15:26 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 10 07:15:26 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 10 07:15:40 PM: Applying reduction GUROBI
# (CVXPY) Jul 10 07:15:42 PM: Finished problem compilation (took 1.648e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 07:15:42 PM: Invoking solver GUROBI  to obtain a solution.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (mac64[x86] - Darwin 24.4.0 24E263)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  500
# QCPDual  1
#
# Optimize a model with 109201 rows, 110301 columns and 674200 nonzeros
# Model fingerprint: 0xa5241478
# Model has 2000 quadratic constraints
# Variable types: 110101 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e-06, 1e+01]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 07:24:05 PM: Problem status: user_limit
# (CVXPY) Jul 10 07:24:05 PM: Optimal value: -6.268e+01
# (CVXPY) Jul 10 07:24:05 PM: Compilation took 1.648e+01 seconds
# (CVXPY) Jul 10 07:24:05 PM: Solver (including time spent in interface) took 5.034e+02 seconds
#
# end of glob
#
# ULO start
#
# tested piece #31
# value: -61.35788477070497
# tested piece #152
# value: -62.68227851186078
# F_hat = -62.682278511860794
# |S| = 20
# F_check = -62.68227851186078
#
# convergence after 1 iterations
# ULO start
#
# tested piece #190
# value: -62.55438348430893
# F_hat = -62.55438348430892
# |S| = 20
# F_check = -62.686243274704445
# tested piece #152
# value: -62.68227851186078
#
# early convergence within iteration #1
# ULO start
#
# tested piece #47
# value: -61.773575998224764
# tested piece #152
# value: -62.68227851186078
# F_hat = -62.682278511860794
# |S| = 19
# F_check = -62.68227851186078
#
# convergence after 1 iterations
# ULO start
#
# tested piece #152
# value: -62.68227851186078
# F_hat = -62.682278511860794
# |S| = 20
# F_check = -62.68227851186078
#
# convergence after 1 iterations
# ULO start
#
# tested piece #8
# value: -60.80642994737293
# tested piece #152
# value: -62.68227851186078
# F_hat = -62.682278511860794
# |S| = 20
# F_check = -62.68227851186078
#
# convergence after 1 iterations
# ULO start
#
# tested piece #196
# value: -61.927312110834286
# tested piece #152
# value: -62.68227851186078
# F_hat = -62.682278511860794
# |S| = 20
# F_check = -62.68227851186078
#
# convergence after 1 iterations
# ULO start
#
# tested piece #114
# value: -60.42048206327119
# tested piece #152
# value: -62.68227851186078
# F_hat = -62.682278511860794
# |S| = 20
# F_check = -62.68227851186078
#
# convergence after 1 iterations
# ULO start
#
# tested piece #144
# value: -60.25475367348555
# tested piece #152
# value: -62.68227851186078
# F_hat = -62.682278511860794
# |S| = 20
# F_check = -62.68227851186078
#
# convergence after 1 iterations
# ULO start
#
# tested piece #81
# value: -60.63966523199713
# tested piece #152
# value: -62.68227851186078
# F_hat = -62.682278511860794
# |S| = 20
# F_check = -62.68227851186078
#
# convergence after 1 iterations
# ULO start
#
# tested piece #93
# value: -60.915470345296335
# tested piece #152
# value: -62.68227851186078
# F_hat = -62.682278511860794
# |S| = 20
# F_check = -62.68227851186078
#
# convergence after 1 iterations
#
# end of ULO
#
# trial #i = 147 took 28.90899109840393 [s]
# trial #i = 188 took 11.714454889297485 [s]
# trial #i = 139 took 12.663198947906494 [s]
# trial #i = 54 took 12.409289836883545 [s]
# trial #i = 166 took 13.44386887550354 [s]
# trial #i = 142 took 14.983422994613647 [s]
# trial #i = 85 took 14.097072124481201 [s]
# trial #i = 183 took 13.92266297340393 [s]
# trial #i = 3 took 11.575515985488892 [s]
# trial #i = 137 took 12.699964761734009 [s]
# trial #i = 179 took 11.612601041793823 [s]
# trial #i = 140 took 14.433200120925903 [s]
# trial #i = 165 took 15.3905668258667 [s]
# trial #i = 29 took 11.700747966766357 [s]
# trial #i = 91 took 12.773741722106934 [s]
# trial #i = 87 took 11.279336929321289 [s]
# trial #i = 129 took 12.36085295677185 [s]
# trial #i = 163 took 11.084619998931885 [s]
# trial #i = 118 took 12.339617013931274 [s]
# trial #i = 23 took 12.982796907424927 [s]
#
# end of ES
#
# => data generation for db = 0.5 and iBd = 0.1
#
# ===============================================================================
#                                      CVXPY
#                                      v1.6.5
# ===============================================================================
# (CVXPY) Jul 10 07:34:01 PM: Your problem has 301 variables, 1201 constraints, and 0 parameters.
# (CVXPY) Jul 10 07:34:01 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 10 07:34:01 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 10 07:34:01 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jul 10 07:34:01 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 07:34:01 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 10 07:34:01 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> GUROBI
# (CVXPY) Jul 10 07:34:01 PM: Applying reduction Dcp2Cone
# (CVXPY) Jul 10 07:34:02 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 10 07:34:02 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 10 07:34:16 PM: Applying reduction GUROBI
# (CVXPY) Jul 10 07:34:18 PM: Finished problem compilation (took 1.750e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 07:34:18 PM: Invoking solver GUROBI  to obtain a solution.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (mac64[x86] - Darwin 24.4.0 24E263)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  500
# QCPDual  1
#
# Optimize a model with 109201 rows, 110301 columns and 674200 nonzeros
# Model fingerprint: 0x2ae014f2
# Model has 2000 quadratic constraints
# Variable types: 110101 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [5e-07, 7e+01]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# No start values specified in MIP start
#
# Presolve removed 2600 rows and 2600 columns
# Presolve time: 2.76s
# Presolved: 108601 rows, 213701 columns, 777000 nonzeros
# Presolved model has 106000 quadratic constraint(s)
# Variable types: 213501 continuous, 200 integer (200 binary)
# Root relaxation presolve removed 99400 rows and 99400 columns
# Root relaxation presolve time: 4.42s
# Root relaxation presolved: 325201 rows, 426301 columns, 1418200 nonzeros
# Root relaxation presolved model has 106000 second-order cone constraints
# Root barrier log...
#
# Ordering time: 0.15s
#
# Barrier statistics:
#  Dense cols : 1100
#  Free vars  : 100
#  AA' NZ     : 1.348e+06
#  Factor NZ  : 3.989e+06 (roughly 340 MB of memory)
#  Factor Ops : 2.801e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.85690222e+03 -7.81280123e+06  6.19e+04 6.95e-01  8.18e+01     6s
#    1   2.31930416e+03 -3.58886604e+06  2.69e+04 1.15e-01  2.99e+01     6s
#    2   8.27645042e+02 -1.01466812e+06  1.30e+03 1.27e-07  2.73e+00     6s
#    3  -5.24012243e+01 -2.10117943e+04  1.56e+00 9.14e-10  3.93e-02     7s
#    4  -5.73021744e+01 -4.67164364e+03  4.42e-01 1.73e-10  8.52e-03     7s
#    5  -6.03933710e+01 -2.52878066e+03  1.50e-01 8.91e-11  4.54e-03     8s
#    6  -6.17799420e+01 -1.46684462e+03  9.86e-02 5.05e-11  2.58e-03     8s
#    7  -6.53267635e+01 -1.00829750e+03  5.64e-02 3.35e-11  1.73e-03     9s
#    8  -6.82300249e+01 -7.59564359e+02  4.20e-02 2.45e-11  1.27e-03     9s
#    9  -7.02188841e+01 -6.03046866e+02  3.59e-02 1.89e-11  9.77e-04     9s
#   10  -7.30390625e+01 -4.74152827e+02  2.98e-02 1.42e-11  7.36e-04    10s
#      5     2 -127.30355    3   12  -92.23937 -127.37739  38.1%   0.0  268s
#      7     2 -127.26192    4   12  -92.23937 -127.30355  38.0%   0.0  296s
# *    8     2               4     -92.5698345 -127.26192  37.5%   0.0  296s
#      9     2 -127.22201    5   11  -92.56983 -127.26192  37.5%   0.0  325s
#     11     2 -127.19106    6   10  -92.56983 -127.22201  37.4%   0.0  387s
# *   12     2               6     -92.9409871 -127.19106  36.9%   0.0  387s
#     13     3 -127.11895    7   13  -92.94099 -127.19106  36.9%   0.0  451s
# *   15     3               7     -93.1452471 -127.11895  36.5%   0.0  451s
#     16     2     cutoff    8       -93.14525 -127.06514  36.4%   0.0  500s
#
# Explored 19 nodes (0 simplex iterations) in 500.46 seconds (356.37 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: -93.1452 -92.941 -92.5698 ... -91.5321
#
# Time limit reached
# Best objective -9.314524707815e+01, best bound -1.270101120399e+02, gap 36.3571%
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 10 07:42:42 PM: Problem status: user_limit
# (CVXPY) Jul 10 07:42:42 PM: Optimal value: -9.315e+01
# (CVXPY) Jul 10 07:42:42 PM: Compilation took 1.750e+01 seconds
# (CVXPY) Jul 10 07:42:42 PM: Solver (including time spent in interface) took 5.039e+02 seconds
#
# end of glob
#
# ULO start
#
# tested piece #98
# value: -78.02748548649367
# F_hat = -78.02748548649367
# |S| = 3
# F_check = -94.6924317305644
# tested piece #54
# value: -94.31058430890701
# F_hat = -94.31058430890701
# |S| = 6
# F_check = -94.56789848168948
# tested piece #194
# value: -94.49982028770401
# F_hat = -94.49982028770403
# |S| = 9
# F_check = -94.49982028770401
#
# convergence after 3 iterations
# ULO start
#
# tested piece #142
# value: -85.94588181186097
# F_hat = -85.94588181186097
# |S| = 4
# F_check = -94.60765899984034
# tested piece #54
# value: -94.31058430890701
# F_hat = -94.31058430890701
# |S| = 7
# F_check = -94.59727140406684
# tested piece #194
# value: -94.49982028770401
# F_hat = -94.49982028770403
# |S| = 10
# F_check = -94.49982028770401
#
# convergence after 3 iterations
# ULO start
#
# tested piece #115
# value: -88.6144150797067
# F_hat = -88.61441507970669
# |S| = 4
# F_check = -94.62300402259683
# tested piece #54
# value: -94.31058430890701
# F_hat = -94.31058430890701
# |S| = 7
# F_check = -94.52708977515299
# tested piece #194
# value: -94.49982028770401
# F_hat = -94.49982028770403
# |S| = 9
# F_check = -94.49982028770401
#
# convergence after 3 iterations
# ULO start
#
# tested piece #1
# value: -83.64825924227638
# F_hat = -83.6482592422764
# |S| = 2
# F_check = -94.92947479491161
# tested piece #194
# value: -94.49982028770401
# F_hat = -94.49982028770403
# |S| = 6
# F_check = -94.62300406111096
# tested piece #54
# value: -94.31058430890701
# F_hat = -94.49982028770403
# |S| = 9
# F_check = -94.49982028770401
#
# convergence after 3 iterations
# ULO start
#
# tested piece #64
# value: -91.39871379452354
# F_hat = -91.39871379452353
# |S| = 4
# F_check = -94.62300403004647
# tested piece #54
# value: -94.31058430890701
# F_hat = -94.31058430890701
# |S| = 7
# F_check = -94.52708948485053
# tested piece #194
# value: -94.49982028770401
# F_hat = -94.49982028770403
# |S| = 9
# F_check = -94.49982028770401
#
# convergence after 3 iterations
# ULO start
#
# tested piece #39
# value: -89.0208770281823
# F_hat = -89.0208770281823
# |S| = 2
# F_check = -94.7990101138995
# tested piece #194
# value: -94.49982028770401
# F_hat = -94.49982028770403
# |S| = 6
# F_check = -94.57443953720522
# tested piece #54
# value: -94.31058430890701
# F_hat = -94.49982028770403
# |S| = 9
# F_check = -94.49982028770401
#
# convergence after 3 iterations
# ULO start
#
# tested piece #91
# value: -89.16178314699522
# F_hat = -89.16178314699522
# |S| = 4
# F_check = -94.78536579559524
# tested piece #54
# value: -94.31058430890701
# F_hat = -94.31058430890701
# |S| = 7
# F_check = -94.56159059961502
# tested piece #194
# value: -94.49982028770401
# F_hat = -94.49982028770403
# |S| = 10
# F_check = -94.49982028770401
#
# convergence after 3 iterations
# ULO start
#
# tested piece #5
# value: -84.81628753233626
# F_hat = -84.81628753233628
# |S| = 2
# F_check = -94.97172702995083
# tested piece #194
# value: -94.49982028770401
# F_hat = -94.49982028770403
# |S| = 6
# F_check = -94.49982028770401
#
# convergence after 2 iterations
# ULO start
#
# tested piece #153
# value: -93.14524183437364
# F_hat = -93.14524183437366
# |S| = 3
# F_check = -94.97172488969075
# tested piece #194
# value: -94.49982028770401
# F_hat = -94.49982028770403
# |S| = 7
# F_check = -94.49982028770401
#
# convergence after 2 iterations
# ULO start
#
# tested piece #106
# value: -89.24410711760501
# F_hat = -89.24410711760501
# |S| = 3
# ...
# |S| = 30
# F_check = -735.9637672459263
# tested piece #162
# value: -722.5175912816809
# F_hat = -722.6587380262984
# |S| = 43
# F_check = -732.4138814275439
# tested piece #95
# value: -718.0465655607471
# F_hat = -722.6587380262984
# |S| = 52
# F_check = -730.2207657726202
# tested piece #24
# value: -714.3921383058142
# F_hat = -722.6587380262984
# |S| = 61
# F_check = -724.2000246551244
# tested piece #26
# value: -707.7171862497071
# F_hat = -722.6587380262984
# |S| = 69
# F_check = -722.6587380262985
#
# convergence after 7 iterations
# ULO start
#
# tested piece #36
# value: -659.6511502885514
# F_hat = -659.6511502885514
# |S| = 7
# F_check = -752.715131095784
# tested piece #174
# value: -722.6587380262985
# F_hat = -722.6587380262984
# |S| = 15
# F_check = -739.4080444213156
# tested piece #64
# value: -719.9633615793236
# F_hat = -722.6587380262984
# |S| = 24
# F_check = -736.9195470971306
# tested piece #162
# value: -722.5175912816809
# F_hat = -722.6587380262984
# |S| = 37
# F_check = -733.3488215750531
# tested piece #95
# value: -718.0465655607471
# F_hat = -722.6587380262984
# |S| = 46
# F_check = -729.0143757440678
# tested piece #24
# value: -714.3921383058142
# F_hat = -722.6587380262984
# |S| = 55
# F_check = -723.1568438956531
# tested piece #91
# value: -712.1408100013671
# F_hat = -722.6587380262984
# |S| = 67
# F_check = -722.6587380262985
#
# convergence after 7 iterations
# ULO start
#
# tested piece #138
# value: -668.2247021158372
# F_hat = -668.2247021158371
# |S| = 10
# F_check = -746.6310007955832
# tested piece #174
# value: -722.6587380262985
# F_hat = -722.6587380262984
# |S| = 18
# F_check = -735.9104077384021
# tested piece #24
# value: -714.3921383058142
# F_hat = -722.6587380262984
# |S| = 27
# F_check = -735.853451344575
# tested piece #95
# value: -718.0465655607471
# F_hat = -722.6587380262984
# |S| = 36
# F_check = -732.8215914889291
# tested piece #162
# value: -722.5175912816809
# F_hat = -722.6587380262984
# |S| = 48
# F_check = -731.717063397634
# tested piece #64
# value: -719.9633615793236
# F_hat = -722.6587380262984
# |S| = 56
# F_check = -725.3169237145838
# tested piece #26
# value: -707.7171862497071
# F_hat = -722.6587380262984
# |S| = 64
# F_check = -723.9718541938142
# tested piece #39
# value: -711.0793364286111
# F_hat = -722.6587380262984
# |S| = 74
# F_check = -722.6587380262985
#
# convergence after 8 iterations
# ULO start
#
# tested piece #85
# value: -665.6353034801426
# F_hat = -665.6353034801425
# |S| = 9
# F_check = -750.7417935776242
# tested piece #174
# value: -722.6587380262985
# F_hat = -722.6587380262984
# |S| = 17
# F_check = -740.3274557870064
# tested piece #64
# value: -719.9633615793236
# F_hat = -722.6587380262984
# |S| = 26
# F_check = -735.5887570081053
# tested piece #95
# value: -718.0465655607471
# F_hat = -722.6587380262984
# |S| = 35
# F_check = -733.9139790503978
# tested piece #162
# value: -722.5175912816809
# F_hat = -722.6587380262984
# |S| = 48
# F_check = -727.4139400678079
# tested piece #24
# value: -714.3921383058142
# F_hat = -722.6587380262984
# |S| = 57
# F_check = -724.2019370169751
# tested piece #91
# value: -712.1408100013671
# F_hat = -722.6587380262984
# |S| = 69
# F_check = -722.6587380262985
#
# convergence after 7 iterations
# ULO start
#
# tested piece #84
# value: -690.9639080191862
# F_hat = -690.9639080191862
# |S| = 8
# F_check = -750.1668992641908
# tested piece #174
# value: -722.6587380262985
# F_hat = -722.6587380262984
# |S| = 16
# F_check = -737.0247982538173
# tested piece #95
# value: -718.0465655607471
# F_hat = -722.6587380262984
# |S| = 25
# F_check = -733.282854909564
# tested piece #64
# value: -719.9633615793236
# F_hat = -722.6587380262984
# |S| = 33
# F_check = -730.9645624205605
# tested piece #162
# value: -722.5175912816809
# F_hat = -722.6587380262984
# |S| = 45
# F_check = -727.1921868340442
# tested piece #24
# value: -714.3921383058142
# F_hat = -722.6587380262984
# |S| = 54
# F_check = -726.1215497514454
# tested piece #26
# value: -707.7171862497071
# F_hat = -722.6587380262984
# |S| = 62
# F_check = -722.6587380262985
#
# convergence after 7 iterations
#
# end of ULO
#
# trial #i = 85 took 22.943551301956177 [s]
# trial #i = 99 took 12.15541672706604 [s]
# trial #i = 145 took 10.978774070739746 [s]
# trial #i = 127 took 12.684326887130737 [s]
# trial #i = 133 took 10.641271114349365 [s]
# trial #i = 11 took 11.145184993743896 [s]
# trial #i = 48 took 9.701189756393433 [s]
# trial #i = 66 took 9.460222959518433 [s]
# trial #i = 126 took 10.773339748382568 [s]
# trial #i = 152 took 9.966252088546753 [s]
# trial #i = 139 took 9.391150951385498 [s]
# trial #i = 69 took 10.98555326461792 [s]
# trial #i = 136 took 10.214407920837402 [s]
# trial #i = 77 took 10.75190782546997 [s]
# trial #i = 42 took 9.351083040237427 [s]
# trial #i = 117 took 10.934984922409058 [s]
# trial #i = 24 took 9.898133039474487 [s]
# trial #i = 62 took 11.798196792602539 [s]
# trial #i = 73 took 10.314220190048218 [s]
# trial #i = 165 took 12.254532814025879 [s]
#
# end of ES
#
# => data generation for db = 10 and iBd = 2
#
# ===============================================================================
#                                      CVXPY
#                                      v1.6.5
# ===============================================================================
# (CVXPY) Jul 11 06:46:42 AM: Your problem has 301 variables, 1201 constraints, and 0 parameters.
# (CVXPY) Jul 11 06:46:42 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jul 11 06:46:42 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jul 11 06:46:42 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jul 11 06:46:42 AM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jul 11 06:46:42 AM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jul 11 06:46:42 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> GUROBI
# (CVXPY) Jul 11 06:46:42 AM: Applying reduction Dcp2Cone
# (CVXPY) Jul 11 06:46:42 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Jul 11 06:46:42 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jul 11 06:46:56 AM: Applying reduction GUROBI
# (CVXPY) Jul 11 06:46:58 AM: Finished problem compilation (took 1.599e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jul 11 06:46:58 AM: Invoking solver GUROBI  to obtain a solution.
# Set parameter OutputFlag to value 1
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (mac64[x86] - Darwin 24.4.0 24E263)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# TimeLimit  500
# QCPDual  1
#
# Optimize a model with 109201 rows, 110301 columns and 674200 nonzeros
# Model fingerprint: 0x765615c1
# Model has 2000 quadratic constraints
# Variable types: 110101 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [7e-07, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# No start values specified in MIP start
#
# Presolve removed 2600 rows and 2600 columns
# Presolve time: 2.51s
# Presolved: 108601 rows, 213701 columns, 777000 nonzeros
# Presolved model has 106000 quadratic constraint(s)
# Variable types: 213501 continuous, 200 integer (200 binary)
# Root relaxation presolve removed 99400 rows and 99400 columns
# Root relaxation presolve time: 4.49s
# Root relaxation presolved: 321201 rows, 426301 columns, 1414200 nonzeros
# Root relaxation presolved model has 106000 second-order cone constraints
# Root barrier log...
#
# Ordering time: 0.15s
#
# Barrier statistics:
#  Dense cols : 1100
#  Free vars  : 100
#  AA' NZ     : 1.336e+06
#  Factor NZ  : 3.523e+06 (roughly 300 MB of memory)
#  Factor Ops : 2.258e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.05437828e+04 -2.20939069e+07  7.19e+04 1.25e+00  3.12e+02     6s
#    1   9.17731040e+03 -1.14991843e+07  3.15e+04 1.62e-01  1.18e+02     6s
#    2   1.99184330e+03 -3.19402251e+06  8.94e+02 1.79e-07  8.19e+00     6s
#    3  -9.20296565e+02 -1.90173043e+05  3.24e+01 3.26e-09  4.21e-01     7s
#    4  -1.00818279e+03 -6.75960784e+04  1.03e+01 1.01e-09  1.39e-01     7s
#    5  -1.02037351e+03 -4.75916802e+04  7.53e+00 6.89e-10  9.56e-02     7s
#    6  -1.03415333e+03 -2.74347145e+04  4.90e+00 3.72e-10  5.32e-02     7s
#    7  -1.05047902e+03 -1.31476431e+04  2.05e+00 1.59e-10  2.34e-02     8s
work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -1105.3479    0   10          - -1105.3479      -     -   18s
#      0     0 -1105.3479    0   10          - -1105.3479      -     -   21s
# H    0     0                    -123.9835169 -1105.3479   792%     -   79s
# H    0     0                    -198.3916158 -1105.3479   457%     -   79s
#      0     2 -1105.3479    0   10 -198.39162 -1105.3479   457%     -  105s
#      1     2 -1101.7225    1   10 -198.39162 -1105.3479   457%   0.0  132s
# *    2     2               1    -683.4783677 -1101.7225  61.2%   0.0  132s
#      3     2 -1100.7185    2   10 -683.47837 -1101.7225  61.2%   0.0  156s
#      5     2 -1100.3477    3   10 -683.47837 -1100.7185  61.0%   0.0  180s
#      7     2 -1099.0146    4    9 -683.47837 -1100.3477  61.0%   0.0  203s
#      9     2 -1098.5966    5   12 -683.47837 -1099.0146  60.8%   0.0  269s
#     11     2 -1097.7770    6   12 -683.47837 -1098.5966  60.7%   0.0  295s
#     13     3 -1097.4661    7   11 -683.47837 -1097.7770  60.6%   0.0  336s
#     16     3     cutoff    8      -683.47837 -1096.1562  60.4%   0.0  381s
# *   17     3               9    -688.7901913 -1096.1562  59.1%   0.0  381s
#     20     3     cutoff   11      -688.79019 -1094.6676  58.9%   0.0  425s
#     24     3     cutoff   13      -688.79019 -1094.2002  58.9%   0.0  470s
#     28     2     cutoff   15      -688.79019 -1091.1814  58.4%   0.0  500s
#
# Explored 31 nodes (0 simplex iterations) in 500.31 seconds (422.85 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: -688.79 -683.478 -123.984
#
# Time limit reached
# Warning: max constraint violation (1.2953e-03) exceeds tolerance
# Best objective -6.887901912942e+02, best bound -1.089689767973e+03, gap 58.2034%
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jul 11 06:55:20 AM: Problem status: user_limit
# (CVXPY) Jul 11 06:55:20 AM: Optimal value: -6.888e+02
# (CVXPY) Jul 11 06:55:20 AM: Compilation took 1.599e+01 seconds
# (CVXPY) Jul 11 06:55:20 AM: Solver (including time spent in interface) took 5.023e+02 seconds
#
# end of glob
#
# ULO start
#
# tested piece #16
# value: -611.9294664256762
# F_hat = -611.9294664256763
# |S| = 16
# F_check = -767.2603253481449
# tested piece #137
# value: -683.478270214169
# F_hat = -683.478270214169
# |S| = 38
# F_check = -738.0660756953753
# tested piece #9
# value: -670.5802876975191
# F_hat = -683.478270214169
# |S| = 55
# F_check = -731.8251356883137
# tested piece #150
# value: -678.581399713835
# F_hat = -683.478270214169
# |S| = 77
# F_check = -724.5892455959539
# tested piece #112
# value: -688.7898406634635
# F_hat = -688.7898406634633
# |S| = 98
# F_check = -716.4783346430825
# tested piece #63
# value: -676.0319998413108
# F_hat = -688.7898406634633
# |S| = 119
# F_check = -710.8249237380096
# tested piece #0
# value: -671.6400082469011
# F_hat = -688.7898406634633
# |S| = 135
# F_check = -706.6563191431134
# tested piece #102
# value: -664.2591776608489
# F_hat = -688.7898406634633
# |S| = 150
# F_check = -702.7277117284264
# tested piece #188
# value: -674.6157926797949
# F_hat = -688.7898406634633
# |S| = 166
# F_check = -701.6578962549297
# tested piece #148
# value: -662.773778867854
# F_hat = -688.7898406634633
# |S| = 182
# F_check = -698.3299161786234
# tested piece #57
# value: -671.318145575598
# F_hat = -688.7898406634633
# |S| = 201
# F_check = -696.2719217530284
# tested piece #8
# value: -668.3619169729777
# F_hat = -688.7898406634633
# |S| = 217
# F_check = -692.0434761061344
# tested piece #22
# value: -671.1388188801525
# F_hat = -688.7898406634633
# |S| = 234
# F_check = -689.9777995112987
# tested piece #14
# value: -664.0477140208172
# F_hat = -688.7898406634633
# |S| = 253
# F_check = -689.7910710673028
# tested piece #186
# value: -673.4043072030031
# F_hat = -688.7898406634633
# |S| = 270
# F_check = -688.7898406634635
#
# convergence after 15 iterations
# ULO start
#
# tested piece #177
# value: -648.5071619838126
# F_hat = -648.5071619838125
# |S| = 23
# F_check = -742.1141001166145
# tested piece #63
# value: -676.0319998413108
# F_hat = -676.0319998413106
# |S| = 45
# F_check = -731.1912811422076
# tested piece #0
# value: -671.6400082469011
# F_hat = -676.0319998413106
# |S| = 63
# F_check = -725.5765195226035
# tested piece #9
# value: -670.5802876975191
# F_hat = -676.0319998413106
# |S| = 80
# KeyboardInterrupt

# %%
my_df_results = pd.DataFrame(data=dic_results)

# %%
my_df_results.to_csv('ulo_extended_results.csv')

# %%
my_df_results
# Out:
#             method  rel_dev_obj  rel_dev_cstr         time       F_hat  rep  \
# 0    bigM (direct)          0.1           0.1   519.785641  -64.819773    1
# 1              ULO          0.1           0.1    25.155650  -65.193933    0
# 2              ULO          0.1           0.1     8.085698  -65.193933    1
# 3              ULO          0.1           0.1     7.821373  -65.193933    2
# 4              ULO          0.1           0.1     7.599181  -65.193933    3
# ..             ...          ...           ...          ...         ...  ...
# 166            ULO         10.0           0.5   256.229927 -722.658738    9
# 167             ES         10.0           0.5  2263.437004 -722.658738    1
# 168  bigM (direct)         10.0           2.0   518.513920 -688.790191    1
# 169            ULO         10.0           2.0  2735.594461 -688.789841    0
# 170             ES         10.0           2.0  2450.471380 -688.789841    1
#
#          F_check
# 0     -70.478789
# 1     -65.193933
# 2     -65.193933
# 3     -65.193933
# 4     -65.193933
# ..           ...
# 166  -722.658738
# 167  -722.658738
# 168 -1089.689768
# 169  -688.789841
# 170  -688.789841
#
# [171 rows x 7 columns]

# %%
for value in my_df_results['rel_dev_obj'].unique():
    for subvalue in my_df_results['rel_dev_cstr'].unique():
        print('set-up : '+str([value,subvalue]))
        sub_df = my_df_results[(my_df_results['rel_dev_obj']==value) & (my_df_results['rel_dev_cstr']==subvalue)]
        vec = np.array((sub_df['F_hat']-sub_df['F_check'])/np.maximum(1,np.abs(sub_df['F_hat'])))
        vec = np.array([vec_elem if np.abs(vec_elem)>1e-7 else 0 for vec_elem in vec])    
        print('rel-gap for glob_opt: '+str(vec[0]*100)[:5]+' % ')
        for met in sub_df['method'].unique():
            print('mean time for '+str(met)+' : '+str(np.mean(sub_df[sub_df['method']==met]['time'])))
        print(' ')
# Out:
# set-up : [0.1, 0.1]
# rel-gap for glob_opt: 8.730 %
# mean time for bigM (direct) : 519.7856409549713
# mean time for ULO : 9.527860355377197
# mean time for ES : 2636.2521028518677
#
# set-up : [0.1, 0.5]
# rel-gap for glob_opt: 9.049 %
# mean time for bigM (direct) : 520.355801820755
# mean time for ULO : 9.946706581115723
# mean time for ES : 2738.6419320106506
#
# set-up : [0.1, 2.0]
# rel-gap for glob_opt: 10.31 %
# mean time for bigM (direct) : 520.0623910427094
# mean time for ULO : 31.91093544960022
# mean time for ES : 2723.765239715576
#
# set-up : [0.5, 0.1]
# rel-gap for glob_opt: 36.35 %
# mean time for bigM (direct) : 521.5730330944061
# mean time for ULO : 31.137296867370605
# mean time for ES : 2762.143738269806
#
# set-up : [0.5, 0.5]
# rel-gap for glob_opt: 33.40 %
# mean time for bigM (direct) : 521.8475389480591
# mean time for ULO : 55.63224003314972
# mean time for ES : 2350.852963924408
#
# set-up : [0.5, 2.0]
# rel-gap for glob_opt: 42.96 %
# mean time for bigM (direct) : 516.8693680763245
# mean time for ULO : 58.720876812934875
# mean time for ES : 2158.0392050743103
#
# set-up : [1.0, 0.1]
# rel-gap for glob_opt: 41.73 %
# mean time for bigM (direct) : 516.3678851127625
# mean time for ULO : 13.410140824317931
# mean time for ES : 2272.3094511032104
#
# set-up : [1.0, 0.5]
# rel-gap for glob_opt: 47.71 %
# mean time for bigM (direct) : 517.3811509609222
# mean time for ULO : 43.67412641048431
# mean time for ES : 2380.230760574341
#
# set-up : [1.0, 2.0]
# rel-gap for glob_opt: 58.02 %
# mean time for bigM (direct) : 516.4918761253357
# mean time for ULO : 327.2961923599243
# mean time for ES : 2209.740090370178
#
# set-up : [5.0, 0.1]
# rel-gap for glob_opt: 33.99 %
# mean time for bigM (direct) : 516.5875461101532
# mean time for ULO : 15.796628975868225
# mean time for ES : 2253.2313323020935
#
# set-up : [5.0, 0.5]
# rel-gap for glob_opt: 43.36 %
# mean time for bigM (direct) : 516.24556183815
# mean time for ULO : 118.7980360031128
# mean time for ES : 2310.4409408569336
#
# set-up : [5.0, 2.0]
# rel-gap for glob_opt: 61.03 %
# mean time for bigM (direct) : 515.766804933548
# mean time for ULO : 2163.0709142208098
# mean time for ES : 2150.939028263092
#
# set-up : [10.0, 0.1]
# rel-gap for glob_opt: 38.49 %
# mean time for bigM (direct) : 515.7663507461548
# mean time for ULO : 55.11262998580933
# mean time for ES : 2331.0868620872498
#
# set-up : [10.0, 0.5]
# rel-gap for glob_opt: 43.70 %
# mean time for bigM (direct) : 516.4358758926392
# mean time for ULO : 326.95372838974
# mean time for ES : 2263.4370040893555
#
# set-up : [10.0, 2.0]
# rel-gap for glob_opt: 58.20 %
# mean time for bigM (direct) : 518.5139198303223
# mean time for ULO : 2735.5944612026215
# mean time for ES : 2450.47138
